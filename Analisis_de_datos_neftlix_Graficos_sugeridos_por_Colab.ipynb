# %% [markdown]
# <a href="https://colab.research.google.com/github/ramirezcpatricia1/CodeDataAnalyst/blob/main/Analisis_de_datos_neftlix_Graficos_sugeridos_por_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('NetflixUserbase.csv')

# %%
df
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10   15-01-22         10/6/2023
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 4           5             Basic               10   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14   25-07-22         12/7/2023
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
#
# ...

# %%
x = df['Last Payment Date']
y = df['Monthly Revenue']

# %%
plt.plot(x,y)
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %% [markdown]
# quiero contestar las siguientes preguntas:
#
# 1. que genero genera mayor suscripcion en el año, hombres o mujeres?
#
# 2. cual es el orden de categoria que mas demandan los suscriptores, independiente de su genero
#
# 3.  cual es el orden de categoria que mas demandan los suscriptores segun  su genero
#
# 4. cual es el mes que tiene mayor suscripcion independiente de la categoria
#
# 5. cual es el pais que genera mayor suscripcion
#
# 6. cual es el apis que genera menor suscripcion
#
# 7. que rango de edades son las que mas se suscriben a neftlix
#
# 8. cual es el artefacto por el cual las personas ven neftlix, celular, smartv, laptop

# %% [markdown]
# Preguntas respecto a datos
#
#
# 1. Cuantas observaciones existen
#
# 2. Cuantas variables hay
#
# 3. Necesito todas las observaciones
#
# 4. Necesito todas las variables

# %% [markdown]
# Preguntas respecto a vaCategorizacion de variables
#
# 1. Cuantas variables categoricas existen
#
# 2. cuantas variables continuas existen
#
# 3. como puedo explorar cada ariable respecto a su categoria

# %% [markdown]
# Preguntas respecto a Limpieza y Validación de datos
#
# 1. Tengo datos faltantes
#
# 2. cual es la proporcion de datos faltantes
#
# 3. como puedo tratar los datos faltantes
#
# 4. cual es la distribucion de los datos
#
# 5. TEngo valores atipicos

# %% [markdown]
# Pregutnas respecto a relaicon de variables
#
# 1. existe relacion e trne variables x y Y
#
# 2.Que pasa si ahora considero la variable z en el analisis
#
# 3. que significa que las observaciones se agruppen
#
# 4. que significa el patron qeu se observa

# %% [markdown]
# resumen de mis variables en Neftlix
